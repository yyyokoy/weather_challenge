# %%
import os
import glob
import pandas as pd
import shutil
from datetime import datetime as dt
import datetime

import os
import shutil
import glob
import pandas as pd
from sklearn.model_selection import train_test_split
import cv2
from tqdm import tqdm
import gc
import numpy as np
import hickle as hkl

import warnings
warnings.filterwarnings('ignore')

# %%
SAT_DIR = '../data/input/test/sat'
EXTERNAL_DIR = '../data/external'

# %%
test_info = '../data/input/inference_terms.csv'
test_info_df = pd.read_csv(test_info)
test_info_df.head()
# Out:
#   OpenData_96hr_Start OpenData_96hr_End Inference_24hr_Start  \
# 0      2018/1/2 16:00    2018/1/6 15:00       2018/1/6 16:00
# 1      2018/1/9 16:00   2018/1/13 15:00      2018/1/13 16:00
# 2     2018/1/16 16:00   2018/1/20 15:00      2018/1/20 16:00
# 3     2018/1/23 16:00   2018/1/27 15:00      2018/1/27 16:00
# 4     2018/1/30 16:00    2018/2/3 15:00       2018/2/3 16:00
#
#   Inference_24hr_End  Evaluation_06hr Evaluation_12hr Evaluation_18hr  \
# 0     2018/1/7 15:00   2018/1/6 21:00   2018/1/7 3:00   2018/1/7 9:00
# 1    2018/1/14 15:00  2018/1/13 21:00  2018/1/14 3:00  2018/1/14 9:00
# 2    2018/1/21 15:00  2018/1/20 21:00  2018/1/21 3:00  2018/1/21 9:00
# 3    2018/1/28 15:00  2018/1/27 21:00  2018/1/28 3:00  2018/1/28 9:00
# 4     2018/2/4 15:00   2018/2/3 21:00   2018/2/4 3:00   2018/2/4 9:00
#
#    Evaluation_24hr
# 0   2018/1/7 15:00
# 1  2018/1/14 15:00
# 2  2018/1/21 15:00
# 3  2018/1/28 15:00
# 4   2018/2/4 15:00

# %%
img_list = glob.glob(os.path.join(SAT_DIR, '*/*'))
img_df = pd.DataFrame({'img_path': img_list})
img_df['img_file_name'] = img_df['img_path'].apply(
    lambda x: x.split('/')[-1])
img_df['img_date'] = img_df['img_file_name'].apply(
    lambda x: x.split('.')[0])
img_df['img_date'] = pd.to_datetime(img_df['img_date'])
img_df.index = img_df['img_date']
start_at, end_at = img_df['img_date'].min(), img_df['img_date'].max()
img_df = img_df.reindex(pd.date_range(start_at, end_at, freq="H"))
# 欠損データ確認
img_not_exist_df = img_df[img_df['img_date'].isna()]

# すでに欠損データをダミーで置き換えている場合
if len(img_df[img_df['img_date'].isna()]) == 0:
    img_not_exist_df = img_df[img_df['img_file_name'].str.contains(
        'dummy')]
    img_df = img_df[~img_df['img_file_name'].str.contains('dummy')]

img_not_exist_df['img_date'] = img_not_exist_df.index.values
img_not_exist_df['img_date'] = img_not_exist_df['img_date'].dt.strftime(
    '%Y-%m-%d-%H-%M')
img_not_exist_df['img_file_name'] = img_not_exist_df['img_date'] + \
    '.dummy.fv.png'
img_not_exist_df['img_year'] = img_not_exist_df['img_file_name'].apply(
    lambda x: x.split('-')[0])
img_not_exist_df['img_month'] = img_not_exist_df['img_file_name'].apply(
    lambda x: x.split('-')[1])
img_not_exist_df['img_day'] = img_not_exist_df['img_file_name'].apply(
    lambda x: x.split('-')[2])
img_not_exist_df['img_yyyy-mm-dd'] = img_not_exist_df['img_year'] + \
    '-'+img_not_exist_df['img_month'] + '-' + img_not_exist_df['img_day']
img_not_exist_df['img_path'] = SAT_DIR + '/' + \
    img_not_exist_df['img_yyyy-mm-dd'] + \
    '/' + img_not_exist_df['img_file_name']
img_not_exist_df = img_not_exist_df[['img_path', 'img_file_name']]
img_not_exist_df = img_not_exist_df.assign(file_not_exist=1)
print('number of missing data: {}'.format(len(img_not_exist_df)))
img_df = img_df.drop('img_date', axis=1)
img_df = img_df.dropna()
img_df = img_df.assign(file_not_exist=0)

img_df = pd.concat([img_df, img_not_exist_df]).sort_index()
img_df = img_df.reset_index(drop=True)

if not os.path.exists(EXTERNAL_DIR):
    os.mkdir(EXTERNAL_DIR)
img_df.to_csv(os.path.join(EXTERNAL_DIR, 'test_img_path_info.csv'))
# Out:
# number of missing data: 3883

# %%
img_df = pd.read_csv(os.path.join(EXTERNAL_DIR, 'test_img_path_info.csv'))
for index, row in img_df[img_df['file_not_exist'] == 1].iterrows():
    base_dir = os.path.split(row.img_path)[0]
    if not os.path.exists(base_dir):
        os.mkdir(base_dir)
    try:
        shutil.copyfile(img_df.iloc[index-1].img_path, row.img_path)
    except FileNotFoundError:
        pass

# %%
all_filepaths = []
for end_date in test_info_df.OpenData_96hr_End:
    filepaths = []
    end_date = dt.strptime(end_date, '%Y/%m/%d %H:%M')
    dir_name = end_date.strftime('%Y-%m-%d')
    filename = end_date.strftime('%Y-%m-%d-%H-%M')
    filepath = f'../data/input/test/sat/{dir_name}/{filename}.fv.png'
    filepaths.append(filepath)
    for t in range(1,24):
        
        date = end_date - datetime.timedelta(hours=t)
        dir_name = date.strftime('%Y-%m-%d')
        filename = date.strftime('%Y-%m-%d-%H-%M')

        filepath = f'../data/input/test/sat/{dir_name}/{filename}.fv.png'
        filepaths.append(filepath)
        filepaths = sorted(filepaths)
    for _ in range(0,24):
        filepaths.append('none')
    all_filepaths += filepaths
all_filepaths
# Out:
# ['../data/input/test/sat/2018-01-05/2018-01-05-16-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-17-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-18-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-19-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-20-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-21-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-22-00.fv.png',
#  '../data/input/test/sat/2018-01-05/2018-01-05-23-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-00-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-01-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-02-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-03-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-04-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-05-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-06-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-07-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-08-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-09-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-10-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-11-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-12-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-13-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-14-00.fv.png',
#  '../data/input/test/sat/2018-01-06/2018-01-06-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-01-12/2018-01-12-16-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-17-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-18-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-19-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-20-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-21-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-22-00.fv.png',
#  '../data/input/test/sat/2018-01-12/2018-01-12-23-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-00-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-01-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-02-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-03-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-04-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-05-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-06-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-07-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13-08-00.fv.png',
#  '../data/input/test/sat/2018-01-13/2018-01-13
15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-05-04/2018-05-04-16-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-17-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-18-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-19-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-20-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-21-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-22-00.fv.png',
#  '../data/input/test/sat/2018-05-04/2018-05-04-23-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-00-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-01-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-02-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-03-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-04-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-05-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-06-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-07-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-08-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-09-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-10-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-11-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-12-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-13-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-14-00.fv.png',
#  '../data/input/test/sat/2018-05-05/2018-05-05-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-05-11/2018-05-11-16-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-17-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-18-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-19-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-20-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-21-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-22-00.fv.png',
#  '../data/input/test/sat/2018-05-11/2018-05-11-23-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-00-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-01-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-02-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-03-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-04-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-05-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-06-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-07-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-08-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-09-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-10-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-11-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-12-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-13-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-14-00.fv.png',
#  '../data/input/test/sat/2018-05-12/2018-05-12-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-05-18/2018-05-18-16-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-17-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-18-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-19-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-20-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-21-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-22-00.fv.png',
#  '../data/input/test/sat/2018-05-18/2018-05-18-23-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-00-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-01-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-02-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-03-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-04-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-05-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-06-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-07-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-08-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-09-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-10-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-11-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-12-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-13-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-14-00.fv.png',
#  '../data/input/test/sat/2018-05-19/2018-05-19-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-05-25/2018-05-25-16-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-17-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-18-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-19-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-20-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-21-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-22-00.fv.png',
#  '../data/input/test/sat/2018-05-25/2018-05-25-23-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-00-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-01-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-02-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-03-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-04-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-05-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-06-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-07-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-08-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-09-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-10-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-11-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-12-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-13-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-14-00.fv.png',
#  '../data/input/test/sat/2018-05-26/2018-05-26-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-06-01/2018-06-01-16-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-17-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-18-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-19-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-20-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-21-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-22-00.fv.png',
#  '../data/input/test/sat/2018-06-01/2018-06-01-23-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-00-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-01-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-02-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-03-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-04-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-05-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-06-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-07-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-08-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-09-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-10-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-11-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-12-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-13-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-14-00.fv.png',
#  '../data/input/test/sat/2018-06-02/2018-06-02-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  '../data/input/test/sat/2018-06-08/2018-06-08-16-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-17-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-18-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-19-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-20-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-21-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-22-00.fv.png',
#  '../data/input/test/sat/2018-06-08/2018-06-08-23-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-00-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-01-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-02-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-03-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-04-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-05-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-06-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-07-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-08-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-09-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-10-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-11-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-12-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-13-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-14-00.fv.png',
#  '../data/input/test/sat/2018-06-09/2018-06-09-15-00.fv.png',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  ...]

# %%
minimizing_im_sz = 4
desired_im_sz = (512//minimizing_im_sz, 672//minimizing_im_sz) # (w, h)
DATA_DIR = '../data/features'

# %%
nt = 48
cur_loc = 0
test_starts = []
while cur_loc < len(all_filepaths) - nt + 1:
    test_starts.append(cur_loc)
    cur_loc += nt
test_starts
im_list = []
source_list = []
for loc in test_starts:
    source_list += [loc] * nt
print('Creating test data: ' + str(len(filepaths)) + ' images')
X = []
for im_file in tqdm(all_filepaths):
    if im_file == 'none':
        img = np.zeros(desired_im_sz)
    else:
        img = cv2.imread(im_file, cv2.IMREAD_GRAYSCALE)
    try:
        img = cv2.resize(img, dsize=desired_im_sz,
                         interpolation=cv2.INTER_CUBIC)
    except:
        split1 = os.path.splitext(im_file)
        split2 = os.path.splitext(split1[0])
        dummy_file = split2[0] + '.dummy' + split2[1] + split1[1]
        img = cv2.imread(dummy_file, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, dsize=desired_im_sz,
                 interpolation=cv2.INTER_CUBIC)
    img = img.tolist()
    X.append(img)
    del img
    gc.collect()
X = np.asarray(X)
# Out:
#   0%|          | 1/2400 [00:00<05:11,  7.70it/s]
# Creating test data: 48 images
# 100%|██████████| 2400/2400 [19:24<00:00,  2.06it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1ada5d9264e8> in <module>
#      32     gc.collect()
#      33 X = np.asarray(X)
# ---> 34 X = X.reshape(len(filepaths), desired_im_sz[1], desired_im_sz[0], 1) # (len, h, w, ch)
#      35 print(X.shape)
#      36 if not os.path.exists(DATA_DIR): os.mkdir(DATA_DIR)
#
# ValueError: cannot reshape array of size 51609600 into shape (48,168,128,1)

# %%
X = X.reshape(len(all_filepaths), desired_im_sz[1], desired_im_sz[0], 1) # (len, h, w, ch)
print(X.shape)
if not os.path.exists(DATA_DIR): os.mkdir(DATA_DIR)
hkl.dump(X, os.path.join(DATA_DIR, 'X_test.hkl'))
hkl.dump(source_list, os.path.join(
    DATA_DIR, 'sources_test.hkl'))
# Out:
# (2400, 168, 128, 1)
